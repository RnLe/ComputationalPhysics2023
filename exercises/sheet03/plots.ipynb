# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize the 1x3 subplot
fig, axs = plt.subplots(3, 1, figsize=(8, 15))

# List of data files
files = ["b)set_n4.dat", "b)set_n8.dat", "b)set_n16.dat"]

# Iterate over each subplot and data file
for ax, file in zip(axs, files):
    # Read the data from the file
    time, T, Ekin, Epot, vx, vy = np.genfromtxt(file, skip_header=True, delimiter=',', unpack=True)

    # Create the plot with multiple y-axes
    ax1 = ax
    ax2 = ax1.twinx()
    ax3 = ax1.twinx()

    # Move the spine of the third axis to the right
    ax3.spines['right'].set_position(('outward', 60))

    # Plot the data on the respective axes
    ax1.plot(time[2::100], T[2::100], 'x', label='T', color='tab:blue', markersize=3)
    ax2.plot(time[2:], Ekin[2:], label='Ekin', color='tab:orange')
    ax3.plot(time[2:], Epot[2:], label='Epot', color='tab:green')

    # Set plot labels and title
    ax1.set_xlabel('Time')
    ax1.set_ylabel('T', color='tab:blue')
    ax2.set_ylabel('Ekin', color='tab:orange')
    ax3.set_ylabel('Epot', color='tab:green')
    ax.set_title(f'Time-Resolved Data ({file})')

    # Add a legend
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')
    ax3.legend(loc='center right')

# Adjust layout to avoid overlapping
plt.tight_layout()

# Save and show the plot
fig.savefig("b)sets.pdf")
plt.show()

# %%
files = ["b)g_n4.dat", "b)g_n8.dat", "b)g_n16.dat"]

# Initialize the 1x3 subplot
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Iterate over each subplot and data file
for ax, file in zip(axs, files):
    # Read the data from the file
    rBin, g = np.genfromtxt(file, delimiter=",", skip_header=True, unpack=True)

    # Plot the data on the respective axes
    ax.plot(rBin, g)
    ax.set_xlim(0, (rBin[-1]//2) + 2)

    # Set plot labels and title
    ax.set_xlabel('Distance')
    ax.set_ylabel('Probability')
    ax.set_title(f'Pair correlation function ({file})')

# Adjust layout to avoid overlapping
plt.tight_layout()

# Save and show the plot
fig.savefig("b)g.pdf")
plt.show()

# %% [markdown]
# files = ["b)r_n4.dat", "b)r_n8.dat", "b)r_n16.dat"]
#
# # Initialize the 1x3 subplot
# fig, axs = plt.subplots(1, 3, figsize=(15, 5))
#
# # Iterate over each subplot and data file
# for ax, file in zip(axs, files):
#     # Read the data from the file
#     x, y = np.genfromtxt(file, delimiter=",", skip_header=True, unpack=True)
#
#     # Plot the data on the respective axes
#     ax.scatter(x, y)
#
#     # Set plot labels and title
#     ax.set_xlabel('x')
#     ax.set_ylabel('y')
#     ax.set_title(f'End positions of particles ({file})')
#
# # Adjust layout to avoid overlapping
# plt.tight_layout()
#
# # Save and show the plot
# fig.savefig("b)r.pdf")
# plt.show()

# %%
# Initialize the 1x3 subplot
fig, axs = plt.subplots(3, 1, figsize=(8, 15))

# List of data files
files = ["c)set0.01.dat", "c)set1.dat", "c)set100.dat"]

# Iterate over each subplot and data file
for ax, file in zip(axs, files):
    # Read the data from the file
    time, T, Ekin, Epot, vx, vy = np.genfromtxt(file, skip_header=True, delimiter=',', unpack=True)

    # Create the plot with multiple y-axes
    ax1 = ax
    ax2 = ax1.twinx()
    ax3 = ax1.twinx()

    # Move the spine of the third axis to the right
    ax3.spines['right'].set_position(('outward', 60))

    # Plot the data on the respective axes
    ax1.plot(time[2:], T[2:], 'x', label='T', color='tab:blue', markersize=3)
    ax2.plot(time[2:], Ekin[2:], label='Ekin', color='tab:orange')
    ax3.plot(time[2:], Epot[2:], label='Epot', color='tab:green')

    # Set plot labels and title
    ax1.set_xlabel('Time')
    ax1.set_ylabel('T', color='tab:blue')
    ax2.set_ylabel('Ekin', color='tab:orange')
    ax3.set_ylabel('Epot', color='tab:green')
    ax.set_title(f'Time-Resolved Data ({file})')

    # Add a legend
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')
    ax3.legend(loc='center right')

# Adjust layout to avoid overlapping
plt.tight_layout()

# Save and show the plot
fig.savefig("c)sets.pdf")
plt.show()

# %%
files = ["c)g0.01.dat", "c)g1.dat", "c)g100.dat"]

# Initialize the 1x3 subplot
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Iterate over each subplot and data file
for ax, file in zip(axs, files):
    # Read the data from the file
    rBin, g = np.genfromtxt(file, delimiter=",", skip_header=True, unpack=True)

    # Plot the data on the respective axes
    ax.plot(rBin, g)
    ax.set_xlim(0, (rBin[-1]//2) + 2)

    # Set plot labels and title
    ax.set_xlabel('Distance')
    ax.set_ylabel('Probability')
    ax.set_title(f'Pair correlation function ({file})')

# Adjust layout to avoid overlapping
plt.tight_layout()

# Save and show the plot
fig.savefig("c)g.pdf")
plt.show()

# %% [markdown]
# files = ["c)r0.01.dat", "c)r1.dat", "c)r100.dat"]
#
# # Initialize the 1x3 subplot
# fig, axs = plt.subplots(1, 3, figsize=(15, 5))
#
# # Iterate over each subplot and data file
# for ax, file in zip(axs, files):
#     # Read the data from the file
#     x, y = np.genfromtxt(file, delimiter=",", skip_header=True, unpack=True)
#
#     # Plot the data on the respective axes
#     ax.scatter(x, y)
#
#     # Set plot labels and title
#     ax.set_xlabel('x')
#     ax.set_ylabel('y')
#     ax.set_title(f'End positions of particles ({file})')
#
# # Adjust layout to avoid overlapping
# plt.tight_layout()
#
# # Save and show the plot
# fig.savefig("c)r.pdf")
# plt.show()

# %%
# Initialize the 1x3 subplot
fig, axs = plt.subplots(3, 1, figsize=(8, 15))

# List of data files
files = ["d)set0.01.dat", "d)set1.dat", "d)set100.dat"]

# Iterate over each subplot and data file
for ax, file in zip(axs, files):
    # Read the data from the file
    time, T, Ekin, Epot, vx, vy = np.genfromtxt(file, skip_header=True, delimiter=',', unpack=True)

    # Create the plot with multiple y-axes
    ax1 = ax
    ax2 = ax1.twinx()
    ax3 = ax1.twinx()

    # Move the spine of the third axis to the right
    ax3.spines['right'].set_position(('outward', 60))

    # Plot the data on the respective axes
    ax1.plot(time[2:], T[2:], 'x', label='T', color='tab:blue', markersize=3)
    ax2.plot(time[2:], Ekin[2:], label='Ekin', color='tab:orange')
    ax3.plot(time[2:], Epot[2:], label='Epot', color='tab:green')

    # Set plot labels and title
    ax1.set_xlabel('Time')
    ax1.set_ylabel('T', color='tab:blue')
    ax2.set_ylabel('Ekin', color='tab:orange')
    ax3.set_ylabel('Epot', color='tab:green')
    ax.set_title(f'Time-Resolved Data, isokinetic ({file})')

    # Add a legend
    ax1.legend(loc='upper left')
    ax2.legend(loc='upper right')
    ax3.legend(loc='center right')

# Adjust layout to avoid overlapping
plt.tight_layout()

# Save and show the plot
fig.savefig("d)sets.pdf")
plt.show()

# %%
files = ["d)g0.01.dat", "d)g1.dat", "d)g100.dat"]

# Initialize the 1x3 subplot
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Iterate over each subplot and data file
for ax, file in zip(axs, files):
    # Read the data from the file
    rBin, g = np.genfromtxt(file, delimiter=",", skip_header=True, unpack=True)

    # Plot the data on the respective axes
    ax.plot(rBin, g)
    ax.set_xlim(0, (rBin[-1]//2) + 2)

    # Set plot labels and title
    ax.set_xlabel('Distance')
    ax.set_ylabel('Probability')
    ax.set_title(f'Pair correlation function, isokinetic ({file})')

# Adjust layout to avoid overlapping
plt.tight_layout()

# Save and show the plot
fig.savefig("d)g.pdf")
plt.show()

# %% [markdown]
# files = ["d)r0.01.dat", "d)r1.dat", "d)r100.dat"]
#
# # Initialize the 1x3 subplot
# fig, axs = plt.subplots(1, 3, figsize=(15, 5))
#
# # Iterate over each subplot and data file
# for ax, file in zip(axs, files):
#     # Read the data from the file
#     x, y = np.genfromtxt(file, delimiter=",", skip_header=True, unpack=True)
#
#     # Plot the data on the respective axes
#     ax.scatter(x, y)
#
#     # Set plot labels and title
#     ax.set_xlabel('x')
#     ax.set_ylabel('y')
#     ax.set_title(f'End positions of particles, isokinetic ({file})')
#
# # Adjust layout to avoid overlapping
# plt.tight_layout()
#
# # Save and show the plot
# fig.savefig("d)r.pdf")
# plt.show()
